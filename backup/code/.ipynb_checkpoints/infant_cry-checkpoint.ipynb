# %% [markdown]
# # Infant Cry Language Detection – Introduction & Goals
#
# ## 📌 Introduction
# Babies cry to communicate their needs, but they cannot explain the reason in words.
# For parents, especially new or busy ones, it can be challenging to understand:
# - Is the baby *hungry*?
# - Is the baby *in pain*?
# - Does the baby *need a diaper change*?
# - Is the baby *uncomfortable or sleepy*?
#
# In this project, we will use *Machine Learning* and *Deep Learning* to classify infant cries into meaningful categories based on audio recordings.
#
# ---
#
# ## 🎯 Project Goals
# 1. *Detect and classify baby cries* into specific needs (e.g., hunger, pain, discomfort, etc.).
# 2. Build a *TensorFlow-based model* that can be deployed on web/mobile apps.
# 3. Create a *clean, step-by-step workflow* from raw audio data to model deployment.
# 4. Ensure the model is robust to:
#    - Background noise
#    - Different recording devices
#    - Variations between babies
# 5. Prepare the groundwork for *future health-related features*, such as:
#    - Asking follow-up questions after detecting certain cry types
#    - Suggesting possible health conditions
#
# ---
#
# ## ✅ Success Criteria
# - Model achieves *at least 80% accuracy* on a held-out test set.
# - Model inference time is *fast enough* for real-time use.
# - Code is *reproducible and ready for deployment*.
#
# ---
#
# ## 📂 Dataset
# We will use a dataset containing labeled baby cry audio files, each belonging to one of several categories (e.g., hunger, pain, discomfort).
# We will preprocess these audio clips into features (MFCC, Mel-spectrograms) before feeding them into the model.

# %% [markdown]
# # Core libraries

# %%
import numpy as np
# NumPy: Used for fast numerical computations, arrays, and mathematical operations.

import pandas as pd
import glob
# Pandas: For loading, cleaning, and manipulating datasets (e.g., CSV files).

# --------------------------
# Visualization libraries
# --------------------------

import matplotlib.pyplot as plt
# Matplotlib: Base Python plotting library to create graphs and visualizations.

import seaborn as sns
# Seaborn: Built on Matplotlib; makes creating beautiful, statistical visualizations easier.

# --------------------------
# Machine learning tools
# --------------------------

from sklearn.model_selection import train_test_split
# Splits data into training and testing sets for model evaluation.

from sklearn.preprocessing import LabelEncoder
# Converts text labels (e.g., 'cry', 'noise') into numeric form for ML models.

from sklearn.metrics import classification_report, confusion_matrix
# classification_report: Gives precision, recall, and F1-score.
# confusion_matrix: Shows correct and incorrect predictions.

# --------------------------
# Audio processing libraries
# --------------------------

import librosa
# Librosa: For loading audio files, extracting features (like MFCCs) for ML.

import librosa.display
# Part of Librosa: Displays waveforms, spectrograms, etc.

import soundfile as sf
# SoundFile: Reads and writes sound files (WAV, FLAC, etc.).

# --------------------------
# Deep learning (TensorFlow & Keras)
# --------------------------

import tensorflow as tf
# TensorFlow: Google’s deep learning library, used for training neural networks.

from tensorflow.keras.models import Sequential
# Sequential: Simplest way to build a neural network layer-by-layer.

from tensorflow.keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Flatten
# Dense: Fully connected layer in neural networks.
# Dropout: Prevents overfitting by randomly turning off neurons during training.
# LSTM: Long Short-Term Memory layer for sequence/audio data.
# Conv1D: 1D Convolution layer for extracting patterns from sequences.
# MaxPooling1D: Reduces sequence length, keeps important features.
# Flatten: Converts multi-dimensional data into 1D for Dense layers.

# --------------------------
# Warnings control
# --------------------------

import warnings
warnings.filterwarnings('ignore')
# Suppresses unnecessary warning messages in the output.

# %% [markdown]
# # 2.Project Configuration

# %%
import os

# Path to dataset
DATASET_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset"

# Audio settings
SAMPLE_RATE = 22050  # Common for speech/cry processing
CLIP_DURATION = 5.0  # In seconds
SAMPLES_PER_CLIP = int(SAMPLE_RATE * CLIP_DURATION)

# Label map: maps folder names to numeric labels
LABEL_MAP = {
    "belly_pain": 0,
    "burping": 1,
    "cold_hot": 2,
    "discomfort": 3,
    "hungry": 4,
    "laugh": 5,
    "lonely": 6,
    "noise": 7,
    "scared": 8,
    "silence": 9,
    "tired": 10
}

# Reverse label map (for predictions -> human readable)
INV_LABEL_MAP = {v: k for k, v in LABEL_MAP.items()}

# Verify dataset structure
print("Dataset Path:", DATASET_PATH)
print("Subfolders:", os.listdir(DATASET_PATH))
print("Number of Classes:", len(LABEL_MAP))
# Out:
# Dataset Path: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset
# Subfolders: ['belly_pain', 'burping', 'cold_hot', 'discomfort', 'hungry', 'laugh', 'lonely', 'noise', 'scared', 'silence', 'tired']
# Number of Classes: 11

# %%
from pydub import AudioSegment


# Paths
DATASET_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset"
OUTPUT_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"

os.makedirs(OUTPUT_PATH, exist_ok=True)

# Loop through each subfolder (e.g., "burping", "lonely")
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    
    # Skip if not a directory
    if not os.path.isdir(folder_path):
        continue
    
    output_folder = os.path.join(OUTPUT_PATH, folder)
    os.makedirs(output_folder, exist_ok=True)

    # Process ALL files in the folder (not just specific extensions)
    for file_path in glob.glob(os.path.join(folder_path, "*")):
        try:
            # Skip if already a WAV file (optional: set force_convert=True to reconvert WAVs too)
            if file_path.lower().endswith(".wav"):
                continue

            # Load audio (pydub auto-detects format)
            audio = AudioSegment.from_file(file_path)
            
            # Generate output filename (change extension to .wav)
            filename = os.path.splitext(os.path.basename(file_path))[0] + ".wav"
            output_path = os.path.join(output_folder, filename)
            
            # Export as WAV
            audio.export(output_path, format="wav")
            print(f"✅ Converted: {file_path} → {output_path}")

        except Exception as e:
            print(f"❌ Failed to convert {file_path}: {e}")

print("\n🎉 All non-WAV files converted to WAV!")
# Out:
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\belly_pain\bp-17.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-17.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\belly_pain\bp-18.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-18.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\belly_pain\bp-2.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-2.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\belly_pain\bp-21.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-21.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\belly_pain\bp-22.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-22.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\belly_pain\bp-23.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-23.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\burping\bu-13 - Copy.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-13 - Copy.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\burping\bu-13.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-13.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\burping\bu-16 - Copy.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-16 - Copy.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\burping\bu-16.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-16.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\burping\bu-4 - Copy.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-4 - Copy.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\burping\bu-4.3gp → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-4.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\61c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\61c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\62c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\62c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\63c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\63c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\64c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\64c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\65c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\65c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\66c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\66c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\67c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\67c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset\cold_hot\68c.ogg → C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\68c.wav
# ✅ Converted: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset
:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"

# Create a list to store file paths and labels
data_records = []

# Loop over each class folder using LABEL_MAP from Step 3
for label_name, label_id in LABEL_MAP.items():
    folder_path = os.path.join(DATASET_WAV_PATH, label_name)
    if not os.path.exists(folder_path):
        print(f"Warning: Folder '{folder_path}' not found.")
        continue
    
    # Get all audio files (WAV format)
    wav_files = glob.glob(os.path.join(folder_path, "*.wav"))
    if not wav_files:
        print(f"⚠ No WAV files found in: {folder_path}")
        continue
    
    for file_path in wav_files:
        data_records.append({
            "file_path": file_path,
            "label": label_id,
            "label_name": label_name
        })
    
    print(f"✅ {label_name}: {len(wav_files)} files")

# Convert list to DataFrame
df = pd.DataFrame(data_records)

# Display summary
print(f"\n✅ Total audio files loaded: {len(df)}")
print(f"✅ Number of classes: {df['label_name'].nunique()}")
print("\nSample data:")
print(df.sample(5))
# Out:
# ✅ belly_pain: 6 files
# ✅ burping: 6 files
# ✅ cold_hot: 23 files
# ✅ discomfort: 4 files
# ✅ hungry: 15 files
# ⚠ No WAV files found in: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\laugh
# ✅ lonely: 14 files
# ✅ noise: 108 files
# ✅ scared: 13 files
# ⚠ No WAV files found in: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\silence
# ✅ tired: 6 files
#
# ✅ Total audio files loaded: 195
# ✅ Number of classes: 9
#
# Sample data:
#                                              file_path  label  label_name
# 163  C:\Users\Hussein\Desktop\baby_cries_language\B...      7       noise
# 157  C:\Users\Hussein\Desktop\baby_cries_language\B...      7       noise
# 5    C:\Users\Hussein\Desktop\baby_cries_language\B...      0  belly_pain
# 37   C:\Users\Hussein\Desktop\baby_cries_language\B...      3  discomfort
# 74   C:\Users\Hussein\Desktop\baby_cries_language\B...      7       noise

# %%
# for label_name, label_id in LABEL_MAP.items():
#     folder_path = os.path.join(DATASET_WAV_PATH, label_name)
    
#     if not os.path.exists(folder_path):
#         print(f"❌ Missing folder: {label_name}")
#         continue
    
#     wav_files = glob.glob(os.path.join(folder_path, "*.wav"))
    
#     if not wav_files:
#         print(f"⚠ No WAV files found in: {label_name}")
#     else:
#         print(f"✅ {label_name}: {len(wav_files)} files")

# %% [markdown]
# # Step 5: Data Visualization

# %%
# --------------------------

# --------------------------



# Set style
sns.set(style="whitegrid")

def explore_audio_dataset(df, sample_rate=22050, index=None):
    """
    Performs full EDA on the audio dataset:
    - Class distribution
    - Duration distribution
    - RMS energy
    - Zero Crossing Rate
    - Chroma
    - Waveform, Spectrogram, MFCC for selected index
    
    Parameters:
    - df: DataFrame with 'file_path' and 'label_name'
    - sample_rate: Sampling rate for librosa.load
    - index: If given, plots detailed features for that file
    """
    
    # 1. Class distribution
    plt.figure(figsize=(8,5))
    sns.countplot(data=df, x='label_name', order=df['label_name'].value_counts().index)
    plt.xticks(rotation=45)
    plt.title("Number of Samples per Class")
    plt.show()

    # 2. Duration distribution
    print("⏳ Calculating durations...")
    df['duration_sec'] = df['file_path'].apply(lambda fp: librosa.get_duration(filename=fp))
    plt.figure(figsize=(8,5))
    sns.histplot(df['duration_sec'], bins=30, kde=True)
    plt.xlabel("Duration (seconds)")
    plt.title("Distribution of Audio Durations")
    plt.show()

    # 3. Multi-file waveform overlay (5 random samples)
    plt.figure(figsize=(10,4))
    for path in df['file_path'].sample(min(5, len(df))):
        y, _ = librosa.load(path, sr=sample_rate)
        plt.plot(y, alpha=0.5)
    plt.title("Overlay of 5 Random Waveforms")
    plt.show()

    # 4. If index provided, show detailed plots for that file
    if index is not None:
        if index < 0 or index >= len(df):
            print(f"⚠ Index {index} is out of range (0 to {len(df)-1}).")
            return
        
        file_path = df['file_path'].iloc[index]
        label_name = df['label_name'].iloc[index]
        print(f"🎯 Detailed Analysis for index={index}, label={label_name}")
        
        y, sr = librosa.load(file_path, sr=sample_rate)
        
        
    print("✅ EDA Completed.")

# Example usage:
# Full dataset EDA
explore_audio_dataset(df, sample_rate=22050)

# EDA + detailed file view
# explore_audio_dataset(df, sample_rate=22050, index=7)
# Out:
# ⏳ Calculating durations...
# ✅ EDA Completed.

# %% [markdown]
# # 📊 Dataset Analysis Overview
#
# ---
#
# ## 1️⃣ Class Distribution (Bar Plot)
#
# *What it shows:*
# How many samples exist for each emotion/class in your dataset.
#
# *Example from your graph:*
# - *Hungry* is the largest category (~400 samples)
# - *Lonely* has very few samples (<20)
#
# *Effect:*
# This reveals *class imbalance*.
# Models trained on imbalanced datasets tend to perform well on majority classes and poorly on minority ones.
# ➡ In our case, "hungry" might dominate training accuracy, but "lonely" could be hard for the model to detect.
#
# *What to do:*
# - *Option 1:* Collect more samples for underrepresented classes.
# - *Option 2:* Use data augmentation (pitch shifting, time stretching, adding noise) for minority classes.
# - *Option 3:* Use *class weights* in our model’s loss function so rare classes are given more importance.
#
# ---
#
# ## 2️⃣ Duration Distribution (Histogram + KDE)
#
# *What it shows:*
# The spread of audio durations across our dataset.
# Looks like most files are around *5 seconds*, with a few slightly longer or shorter.
#
# *Effect:*
# Large variation in duration can cause *inconsistent input sizes* for the model.
# - Very short files might lose info after padding.
# - Very long files might be cut off.
#
# *What to do:*
# Decide on a fixed duration for all audio (e.g., *5 seconds*) and either:
# - Trim longer files
# - Pad shorter ones with silence
# OR
# - Use variable-length input methods (advanced: recurrent models that handle varying time steps)
#
# ---
#
# ## 3️⃣ Overlay of Random Waveforms
#
# *What it shows:*
# A few randomly selected audio waveforms overlaid.
# we can see:
# - Amplitude differences (loudness)
# - Patterns in sound events (bursts of energy)
#
# *Effect:*
# May reveal *amplitude imbalance*:
# - Some recordings are very quiet, others loud.
# - The model may learn more from volume than from actual sound patterns → *bad*.
#
# *What to do:*
# Apply *volume normalization* so all audio is roughly the same loudness before feature extraction.
# - Especially important before converting to *spectrograms* or *MFCCs*.
#
# ---
#
# ✅

# %%
def check_data_quality(df, sample_rate=22050):
    issues = {
        "missing_files": [],
        "corrupted_files": [],
        "duplicates": [],
        "outliers": []
    }
    
    seen_hashes = set()
    
    for i, row in df.iterrows():
        file_path = row['file_path']
        label = row['label_name']
        
        # 1. Check missing file
        if not os.path.exists(file_path):
            issues["missing_files"].append(file_path)
            continue
        
        try:
            # 2. Try loading audio
            y, sr = librosa.load(file_path, sr=sample_rate)
            
            # Handle empty/corrupted
            if y is None or len(y) == 0:
                issues["corrupted_files"].append(file_path)
                continue
            
            # 3. Check duplicates by hashing raw signal
            hash_val = hash(y.tobytes())
            if hash_val in seen_hashes:
                issues["duplicates"].append(file_path)
            else:
                seen_hashes.add(hash_val)
            
            # 4. Outlier detection (duration extremes)
            duration = librosa.get_duration(y=y, sr=sr)
            if duration < 0.5 or duration > 15:  # arbitrary thresholds
                issues["outliers"].append((file_path, duration))
        
        except Exception as e:
            issues["corrupted_files"].append((file_path, str(e)))
    
    return issues


# Run check
quality_report = check_data_quality(df)
print("🔍 Data Quality Report")
for key, vals in quality_report.items():
    print(f"{key}: {len(vals)} issues")
    if len(vals) > 0:
        print(vals[:5])  # show first few
# Out:
# 🔍 Data Quality Report
# missing_files: 0 issues
# corrupted_files: 0 issues
# duplicates: 22 issues
# ['C:\\Users\\Hussein\\Desktop\\baby_cries_language\\Baby_Dataset_WAV\\burping\\bu-13.wav', 'C:\\Users\\Hussein\\Desktop\\baby_cries_language\\Baby_Dataset_WAV\\burping\\bu-16.wav', 'C:\\Users\\Hussein\\Desktop\\baby_cries_language\\Baby_Dataset_WAV\\burping\\bu-4.wav', 'C:\\Users\\Hussein\\Desktop\\baby_cries_language\\Baby_Dataset_WAV\\cold_hot\\ch-10 - Copy.wav', 'C:\\Users\\Hussein\\Desktop\\baby_cries_language\\Baby_Dataset_WAV\\cold_hot\\ch-10.wav']
# outliers: 0 issues

# %%
import hashlib

# Path to dataset
DATASET_WAV_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"

def file_hash(filepath, block_size=65536):
    """Generate MD5 hash for a file."""
    hasher = hashlib.md5()
    with open(filepath, "rb") as f:
        buf = f.read(block_size)
        while buf:
            hasher.update(buf)
            buf = f.read(block_size)
    return hasher.hexdigest()

def remove_duplicates(dataset_path):
    """Find and remove duplicate .wav files based on file content hash."""
    seen_hashes = {}
    duplicates = []

    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.lower().endswith(".wav"):
                filepath = os.path.join(root, file)
                try:
                    filehash = file_hash(filepath)
                    if filehash in seen_hashes:
                        # Duplicate found
                        duplicates.append(filepath)
                        os.remove(filepath)  # delete duplicate
                        print(f"🗑 Removed duplicate: {filepath}")
                    else:
                        seen_hashes[filehash] = filepath
                except Exception as e:
                    print(f"❌ Error processing {filepath}: {e}")

    print("\n=== Duplicate Removal Report ===")
    print(f"Total duplicates removed: {len(duplicates)}")
    if duplicates:
        print("Sample removed files:")
        print("\n".join(duplicates[:5]))  # show first 5 removed
    else:
        print("No duplicates found.")

# Run duplicate removal
remove_duplicates(DATASET_WAV_PATH)
# Out:
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-13.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-16.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-4.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-10 - Copy.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-10.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-4 - Copy.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-4.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-5 - Copy.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-5.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-6 - Copy.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-6.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-9 - Copy.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-9.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-1.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-12.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-14.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-18.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-3.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-11.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-13.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-15.wav
# 🗑 Removed duplicate: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-4.wav
#
# === Duplicate Removal Report ===
# Total duplicates removed: 22
# Sample removed files:
# C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-13.wav
# C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-16.wav
# C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-4.wav
# C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-10 - Copy.wav
# C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-10.wav

# %% [markdown]
# # step 7: processing and futere extraction

# %%
#resampling 



import soundfile as sf

# Path to your dataset
DATASET_WAV_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"

# Desired sample rate
TARGET_SAMPLE_RATE = 22050

# Output folder (to save resampled files)
OUTPUT_PATH = os.path.join(DATASET_WAV_PATH, "resampled")
os.makedirs(OUTPUT_PATH, exist_ok=True)

def resample_audio(input_path, output_path, target_sr=22050):
    try:
        # Load audio with librosa (will resample automatically)
        y, sr = librosa.load(input_path, sr=target_sr)

        # Save back in WAV format with new sample rate
        sf.write(output_path, y, target_sr)

        print(f"Resampled: {output_path}")
    except Exception as e:
        print(f"Error with {input_path}: {e}")

# Walk through dataset and resample all files
for root, _, files in os.walk(DATASET_WAV_PATH):
    for file in files:
        if file.endswith(".wav"):
            input_file = os.path.join(root, file)
            output_file = os.path.join(OUTPUT_PATH, file)
            resample_audio(input_file, output_file, TARGET_SAMPLE_RATE)

print("✅ Resampling complete! All files saved in 'resampled' folder.")
# Out:
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-17.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-18.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-2.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-21.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-22.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-23.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-13 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-16 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-4 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\61c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\62c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\63c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\64c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\65c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\66c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\67c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\68c.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-10 - Copy (2).wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-4 - Copy (2).wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-5 - Copy (2).wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-6 - Copy (2).wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-9 - Copy (2).wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-10.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-16.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-23.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-30.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-1.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-10.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-14.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-15.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-19.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-21.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-22.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-25.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-27.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-31.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-33.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-4.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-5.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-7.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-8.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-1 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-12 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-13.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-14 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-18 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-19.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-2.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-3 - Copy.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-4.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-100032-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-110389-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-13571-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-13572-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-21421-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-22804-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-30226-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-30344-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-32318-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-34094-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-34094-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-40154-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-47819-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-47819-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-47819-C.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-48298-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-54747-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-56380-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-56380-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-56907-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-59513-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-79113-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-85362-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-97392-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-114280-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-114587-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-116400-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-117271-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-128465-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-128465-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-138465-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-144137-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-56926-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-57191-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-59565-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-59566-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-69131-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-69131-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-70936-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-70938-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-70939-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-72688-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-82274-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-82274-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-123086-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-124795-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-124958-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-130998-A.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-130998-B.wav
# Resampled: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3
:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"

# Parameters
TARGET_SAMPLE_RATE = 22050
TARGET_DURATION = 5  # seconds
TARGET_LENGTH = TARGET_SAMPLE_RATE * TARGET_DURATION  # total samples = 22050 * 5

def trim_and_pad(audio, sr=TARGET_SAMPLE_RATE, target_length=TARGET_LENGTH):
    """
    Trims or pads audio to a fixed target length.
    """
    if len(audio) > target_length:
        # Trim
        audio = audio[:target_length]
    elif len(audio) < target_length:
        # Pad with zeros (silence)
        pad_width = target_length - len(audio)
        audio = np.pad(audio, (0, pad_width), mode='constant')
    return audio

def process_dataset(dataset_path):
    """
    Resamples, trims, and pads all audio files in dataset.
    """
    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.endswith(".wav"):
                file_path = os.path.join(root, file)
                try:
                    # Load with librosa
                    audio, sr = librosa.load(file_path, sr=TARGET_SAMPLE_RATE)

                    # Trim/Pad
                    audio = trim_and_pad(audio, sr)

                    # Save back
                    sf.write(file_path, audio, TARGET_SAMPLE_RATE)
                    print(f"Processed: {file_path}")
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

# Run
process_dataset(DATASET_WAV_PATH)
# Out:
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-17.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-18.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-2.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-21.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-22.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-23.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-13 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-16 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\burping\bu-4 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\61c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\62c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\63c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\64c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\65c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\66c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\67c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\68c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-10 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-4 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-5 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-6 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\cold_hot\ch-9 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\discomfort\dc-10.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\discomfort\dc-16.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\discomfort\dc-23.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\discomfort\dc-30.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-1.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-10.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-14.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-15.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-19.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-21.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-22.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-25.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-27.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-31.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-33.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-4.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-5.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-7.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\hungry\hu-8.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-1 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-12 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-13.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-14 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-18 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-19.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-2.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-3 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\lonely\lo-4.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-100032-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-110389-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-13571-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-13572-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-21421-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-22804-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-30226-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-30344-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-32318-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-34094-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-34094-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-40154-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-47819-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-47819-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-47819-C.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-48298-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-54747-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-56380-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-56380-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-56907-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-59513-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-79113-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-85362-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\1-97392-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-114280-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-114587-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-116400-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-117271-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-128465-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-128465-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-138465-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-144137-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-56926-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-57191-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-59565-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-59566-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-69131-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-69131-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-70936-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-70938-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-70939-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-72688-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-82274-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\2-82274-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-123086-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-124795-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-124958-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-130998-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-130998-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-145577-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-146697-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-151255-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-151557-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-151557-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-153057-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-155130-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-155234-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-161010-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-174840-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-203371-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-203373-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-203374-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-203375-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-203377-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-216280-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-216281-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-216284-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-243726-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-51376-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-51731-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-51731-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-51909-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-51909-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-58772-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-62878-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\3-62878-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-156993-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-161519-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-165813-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-165813-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-180337-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-183882-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-183882-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-184235-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-187769-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-204115-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-204119-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-204121-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-204123-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-216211-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-223125-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\4-223127-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-156999-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-156999-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-156999-C.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-156999-D.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-156999-E.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-188495-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-192191-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-195557-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-242490-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-242491-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-243448-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-243449-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-243450-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-243459-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-243459-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\noise\5-257839-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-100032-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-110389-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-13571-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-13572-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-21421-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-22804-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-30226-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-30344-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-32318-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-34094-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-34094-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-40154-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-47819-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-47819-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-47819-C.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-48298-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-54747-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-56380-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-56380-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-56907-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-59513-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-79113-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-85362-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\1-97392-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-114280-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-114587-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-116400-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-117271-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-128465-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-128465-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-138465-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-144137-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-56926-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-57191-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-59565-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-59566-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-69131-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-69131-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-70936-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-70938-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-70939-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-72688-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-82274-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\2-82274-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-123086-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-124795-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-124958-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-130998-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-130998-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-145577-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-146697-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-151255-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-151557-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-151557-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-153057-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-155130-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-155234-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-161010-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-174840-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-203371-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-203373-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-203374-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-203375-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-203377-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-216280-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-216281-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-216284-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-243726-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-51376-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-51731-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-51731-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-51909-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-51909-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-58772-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-62878-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\3-62878-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-156993-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-161519-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-165813-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-165813-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-180337-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-183882-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-183882-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-184235-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-187769-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-204115-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-204119-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-204121-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-204123-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-216211-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-223125-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\4-223127-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-C.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-D.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-E.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-188495-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-192191-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-195557-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-242490-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-242491-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243448-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243449-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243450-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243459-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243459-B.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-257839-A.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\61c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\62c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\63c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\64c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\65c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\66c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\67c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\68c.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-17.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-18.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-2.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-21.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-22.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-23.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-13 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-16 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-4 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-10 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-4 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-5 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-6 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-9 - Copy (2).wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-10.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-16.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-23.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-30.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-1.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-10.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-14.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-15.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-19.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-21.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-22.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-25.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-27.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-31.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-33.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-4.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-5.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-7.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-8.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-1 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-12 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-13.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-14 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-18 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-19.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-2.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-3 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-4.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-11 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-12.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-13 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-15 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-16.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-17.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-4 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-5.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-9.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-19.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-25.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-3.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-40.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-41.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-42.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-11 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-12.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-13 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-15 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-16.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-17.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-4 - Copy.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-5.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-9.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-19.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-25.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-3.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-40.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-41.wav
# Processed: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-42.wav

# %%
# normalization

DATASET_WAV_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"

# Normalize all audio files
for root, dirs, files in os.walk(DATASET_WAV_PATH):
    for file in files:
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)

            try:
                # Load audio
                y, sr = librosa.load(file_path, sr=22050)  # keep resampled rate

                # --- Normalization ---
                y = y / max(abs(y))   # scale between -1 and 1

                # Overwrite file with normalized audio
                sf.write(file_path, y, sr)
                print(f"Normalized: {file_path}")

            except Exception as e:
                print(f"Error processing {file_path}: {e}")
# Out:
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-17.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\belly_pain\bp-18.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV
A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-B.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-C.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-D.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-156999-E.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-188495-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-192191-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-195557-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-242490-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-242491-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243448-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243449-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243450-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243459-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-243459-B.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\5-257839-A.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\61c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\62c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\63c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\64c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\65c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\66c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\67c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\68c.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-17.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-18.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-2.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-21.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-22.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bp-23.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-13 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-16 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\bu-4 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-10 - Copy (2).wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-4 - Copy (2).wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-5 - Copy (2).wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-6 - Copy (2).wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ch-9 - Copy (2).wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-10.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-16.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-23.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\dc-30.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-1.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-10.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-14.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-15.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-19.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-21.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-22.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-25.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-27.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-31.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-33.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-4.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-5.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-7.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\hu-8.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-1 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-12 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-13.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-14 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-18 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-19.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-2.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-3 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\lo-4.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-11 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-12.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-13 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-15 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-16.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-17.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-4 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-5.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\sc-9.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-19.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-25.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-3.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-40.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-41.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\resampled\ti-42.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-11 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-12.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-13 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-15 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-16.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-17.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-4 - Copy.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-5.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\scared\sc-9.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-19.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-25.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-3.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-40.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-41.wav
# Normalized: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV\tired\ti-42.wav

# %%
import pandas as pd
import numpy as np
import os
import librosa
import soundfile as sf
from sklearn.utils import resample
from sklearn.utils.class_weight import compute_class_weight
import shutil

# ==================== CONFIGURATION ====================
DATASET_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV"
BALANCED_DATASET_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_BALANCED"
TARGET_SAMPLES = 400  # Target samples per class
# =======================================================

def augment_audio(y, sr, num_augmentations=5):
    """Create augmented audio versions"""
    augmented = []
    
    for i in range(num_augmentations):
        # Pitch shifting (±1-3 semitones)
        n_steps = np.random.randint(-3, 4)
        if n_steps != 0:
            try:
                y_pitch = librosa.effects.pitch_shift(y, sr=sr, n_steps=n_steps)
                augmented.append(y_pitch)
            except:
                pass
        
        # Time stretching (0.8-1.2x speed)
        rate = np.random.uniform(0.8, 1.2)
        try:
            y_time = librosa.effects.time_stretch(y, rate=rate)
            augmented.append(y_time)
        except:
            pass
        
        # Add slight noise
        if np.random.random() > 0.5:
            noise = np.random.normal(0, 0.002, len(y))
            y_noise = y + noise
            augmented.append(y_noise)
    
    return augmented

def create_balanced_dataset():
    """Main function to balance the entire dataset"""
    
    # Create balanced dataset directory
    if os.path.exists(BALANCED_DATASET_PATH):
        shutil.rmtree(BALANCED_DATASET_PATH)
    os.makedirs(BALANCED_DATASET_PATH)
    
    # Collect all file information
    file_data = []
    for class_name in os.listdir(DATASET_PATH):
        class_path = os.path.join(DATASET_PATH, class_name)
        if os.path.isdir(class_path):
            for file in os.listdir(class_path):
                if file.endswith('.wav'):
                    file_data.append({
                        'file_path': os.path.join(class_path, file),
                        'class': class_name,
                        'filename': file
                    })
    
    df = pd.DataFrame(file_data)
    print("Original class distribution:")
    print(df['class'].value_counts())
    print(f"\nTotal classes: {len(df['class'].unique())}")
    
    # Process each class
    all_files = []
    
    for class_name in df['class'].unique():
        class_files = df[df['class'] == class_name]
        num_original = len(class_files)
        
        print(f"\nProcessing class: {class_name} ({num_original} samples)")
        
        class_output_dir = os.path.join(BALANCED_DATASET_PATH, class_name)
        os.makedirs(class_output_dir, exist_ok=True)
        
        # Copy original files
        for _, row in class_files.iterrows():
            output_path = os.path.join(class_output_dir, row['filename'])
            shutil.copy2(row['file_path'], output_path)
            all_files.append(output_path)
        
        # Calculate how many additional samples we need
        needed_samples = TARGET_SAMPLES - num_original
        
        if needed_samples > 0:
            print(f"  Need {needed_samples} additional samples")
            
            if num_original < 100:  # Very small class: use augmentation
                print("  Using augmentation...")
                # Calculate how many augmentations per file we need
                augmentations_per_file = max(needed_samples // num_original + 1, 3)
                print(f"  Creating {augmentations_per_file} augmentations per file")
                
                created_count = 0
                for file_idx, (_, row) in enumerate(class_files.iterrows()):
                    if created_count >= needed_samples:
                        break
                        
                    try:
                        y, sr = librosa.load(row['file_path'], sr=22050)
                        
                        # Create augmented versions
                        augmented_versions = augment_audio(y, sr, augmentations_per_file)
                        
                        for i, aug_audio in enumerate(augmented_versions):
                            if created_count >= needed_samples:
                                break
                                
                            aug_filename = f"aug_{file_idx}{i}{row['filename']}"
                            aug_path = os.path.join(class_output_dir, aug_filename)
                            sf.write(aug_path, aug_audio, sr)
                            all_files.append(aug_path)
                            created_count += 1
                            
                    except Exception as e:
                        print(f"  Error processing {row['filename']}: {e}")
                        continue
                
                print(f"  Created {created_count} augmented samples")
            
            else:  # Medium class: use oversampling
                print("  Using oversampling...")
                additional_files = resample(
                    class_files,
                    replace=True,
                    n_samples=needed_samples,
                    random_state=42
                )
                
                for i, (_, row) in enumerate(additional_files.iterrows()):
                    new_filename = f"oversampled_{i}_{row['filename']}"
                    new_path = os.path.join(class_output_dir, new_filename)
                    shutil.copy2(row['file_path'], new_path)
                    all_files.append(new_path)
    
    # Create final balanced DataFrame
    balanced_data = []
    for file_path in all_files:
        class_name = os.path.basename(os.path.dirname(file_path))
        balanced_data.append({
            'file_path': file_path,
            'label_name': class_name
        })
    
    df_balanced = pd.DataFrame(balanced_data)
    
    print("\n" + "="*60)
    print("FINAL BALANCED DISTRIBUTION:")
    print("="*60)
    print(df_balanced['label_name'].value_counts())
    
    # Verify all classes have TARGET_SAMPLES
    class_counts = df_balanced['label_name'].value_counts()
    unbalanced_classes = class_counts[class_counts != TARGET_SAMPLES]
    
    if len(unbalanced_classes) > 0:
        print(f"\n❌ WARNING: {len(unbalanced_classes)} classes still not balanced:")
        for cls, count in unbalanced_classes.items():
            print(f"   {cls}: {count} samples (target: {TARGET_SAMPLES})")
    else:
        print(f"\n✅ SUCCESS: All classes have exactly {TARGET_SAMPLES} samples!")
    
    # Calculate class weights for model training
    class_weights = compute_class_weight(
        'balanced',
        classes=np.unique(df_balanced['label_name']),
        y=df_balanced['label_name']
    )
    
    class_weight_dict = dict(enumerate(class_weights))
    print("\nCLASS WEIGHTS for model training:")
    for i, class_name in enumerate(np.unique(df_balanced['label_name'])):
        print(f"  {class_name}: {class_weight_dict[i]:.2f}")
    
    return df_balanced, class_weight_dict

# ==================== CLEAN AND RUN ====================
if __name__ == "__main__":
    # Clean previous run
    if os.path.exists(BALANCED_DATASET_PATH):
        shutil.rmtree(BALANCED_DATASET_PATH)
        print("🧹 Cleaned previous balanced dataset")
    
    print("🚀 Starting dataset balancing...")
    print(f"Source: {DATASET_PATH}")
    print(f"Target: {BALANCED_DATASET_PATH}")
    print(f"Target samples per class: {TARGET_SAMPLES}")
    print("="*60)
    
    balanced_df, class_weights = create_balanced_dataset()
    
    print("\n✅ Dataset balancing complete!")
    print(f"📁 Balanced dataset saved to: {BALANCED_DATASET_PATH}")
    print(f"📊 Total samples: {len(balanced_df)}")
    print(f"🎯 Number of classes: {len(balanced_df['label_name'].unique())}")
    
    # Final verification
    final_counts = balanced_df['label_name'].value_counts()
    if all(count == TARGET_SAMPLES for count in final_counts):
        print("\n PERFECT BALANCE")
    else:
        print("\n⚠  Some classes still need manual adjustment")
# Out:
# 🚀 Starting dataset balancing...
# Source: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_WAV
# Target: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_BALANCED
# Target samples per class: 400
# ============================================================
# Original class distribution:
# class
# resampled     173
# noise         108
# hungry         15
# cold_hot       13
# lonely          9
# scared          9
# belly_pain      6
# tired           6
# discomfort      4
# burping         3
# Name: count, dtype: int64
#
# Total classes: 10
#
# Processing class: belly_pain (6 samples)
#   Need 394 additional samples
#   Using augmentation...
#   Creating 66 augmentations per file
#   Created 394 augmented samples
#
# Processing class: burping (3 samples)
#   Need 397 additional samples
#   Using augmentation...
#   Creating 133 augmentations per file
#   Created 397 augmented samples
#
# Processing class: cold_hot (13 samples)
#   Need 387 additional samples
#   Using augmentation...
#   Creating 30 augmentations per file
#   Created 387 augmented samples
#
# Processing class: discomfort (4 samples)
#   Need 396 additional samples
#   Using augmentation...
#   Creating 100 augmentations per file
#   Created 396 augmented samples
#
# Processing class: hungry (15 samples)
#   Need 385 additional samples
#   Using augmentation...
#   Creating 26 augmentations per file
#   Created 385 augmented samples
#
# Processing class: lonely (9 samples)
#   Need 391 additional samples
#   Using augmentation...
#   Creating 44 augmentations per file
#   Created 391 augmented samples
#
# Processing class: noise (108 samples)
#   Need 292 additional samples
#   Using oversampling...
#
# Processing class: resampled (173 samples)
#   Need 227 additional samples
#   Using oversampling...
#
# Processing class: scared (9 samples)
#   Need 391 additional samples
#   Using augmentation...
#   Creating 44 augmentations per file
#   Created 391 augmented samples
#
# Processing class: tired (6 samples)
#   Need 394 additional samples
#   Using augmentation...
#   Creating 66 augmentations per file
#   Created 394 augmented samples
#
# ============================================================
# FINAL BALANCED DISTRIBUTION:
# ============================================================
# label_name
# belly_pain    400
# burping       400
# cold_hot      400
# discomfort    400
# hungry        400
# lonely        400
# noise         400
# resampled     400
# scared        400
# tired         400
# Name: count, dtype: int64
#
# ✅ SUCCESS: All classes have exactly 400 samples!
#
# CLASS WEIGHTS for model training:
#   belly_pain: 1.00
#   burping: 1.00
#   cold_hot: 1.00
#   discomfort: 1.00
#   hungry: 1.00
#   lonely: 1.00
#   noise: 1.00
#   resampled: 1.00
#   scared: 1.00
#   tired: 1.00
#
# ✅ Dataset balancing complete!
# 📁 Balanced dataset saved to: C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_BALANCED
# 📊 Total samples: 4000
# 🎯 Number of classes: 10
#
#  PERFECT BALANCE

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import librosa
import os
from tqdm import tqdm

# ==================== CONFIGURATION ====================
BALANCED_DATASET_PATH = r"C:\Users\Hussein\Desktop\baby_cries_language\Baby_Dataset_BALANCED"
SAMPLE_RATE = 22050
DURATION = 5  # seconds
MAX_LENGTH = SAMPLE_RATE * DURATION  # 110250 samples
N_MFCC = 40  # Number of MFCC coefficients
# =======================================================

def load_and_preprocess_audio(file_path):
    """Load audio file and convert to MFCC features"""
    try:
        # Load audio
        y, sr = librosa.load(file_path, sr=SAMPLE_RATE)
        
        # Ensure consistent length (5 seconds)
        if len(y) > MAX_LENGTH:
            y = y[:MAX_LENGTH]  # Trim
        else:
            y = np.pad(y, (0, max(0, MAX_LENGTH - len(y))), 'constant')  # Pad
        
        # Extract MFCC features
        mfccs = librosa.feature.mfcc(
            y=y, 
            sr=sr, 
            n_mfcc=N_MFCC,
            n_fft=2048,
            hop_length=512
        )
        
        # Add channel dimension for CNN
        mfccs = np.expand_dims(mfccs, axis=-1)
        
        return mfccs
        
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

def build_dataset_dataframe():
    """Create DataFrame with file paths and labels"""
    data = []
    label_to_id = {}
    
    # Get all classes and assign IDs
    classes = sorted(os.listdir(BALANCED_DATASET_PATH))
    label_to_id = {cls: i for i, cls in enumerate(classes)}
    
    for class_name in classes:
        class_path = os.path.join(BALANCED_DATASET_PATH, class_name)
        if os.path.isdir(class_path):
            for file in os.listdir(class_path):
                if file.endswith('.wav'):
                    data.append({
                        'file_path': os.path.join(class_path, file),
                        'label': label_to_id[class_name],
                        'label_name': class_name
                    })
    
    return pd.DataFrame(data), label_to_id

def create_tf_data_pipeline(df, batch_size=32, shuffle=True):
    """Create optimized tf.data pipeline"""
    
    def process_path(file_path, label):
        # Load and preprocess audio
        audio = tf.numpy_function(
            func=load_and_preprocess_audio,
            inp=[file_path],
            Tout=tf.float32
        )
        audio.set_shape((N_MFCC, 216, 1))  # MFCC shape: (40, 216, 1)
        return audio, label
    
    # Convert DataFrame to TensorFlow Dataset
    file_paths = tf.constant(df['file_path'].values)
    labels = tf.constant(df['label'].values)
    
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))
    
    # Map the preprocessing function
    dataset = dataset.map(
        lambda file_path, label: process_path(file_path, label),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    
    # Optimize the pipeline
    if shuffle:
        dataset = dataset.shuffle(buffer_size=1000)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset

# ==================== MAIN PIPELINE ====================

print("🚀 Building dataset pipeline...")
print("Step 1: Creating file manifest...")

# Build DataFrame with all files
df, label_mapping = build_dataset_dataframe()
print(f"📊 Loaded {len(df)} samples")
print(f"🎯 Classes: {list(label_mapping.keys())}")
print(f"🔢 Label mapping: {label_mapping}")

# Train/Test split
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    df, 
    test_size=0.2, 
    random_state=42,
    stratify=df['label']
)

print(f"\n📈 Dataset split:")
print(f"   Training: {len(train_df)} samples")
print(f"   Testing:  {len(test_df)} samples")

# Create tf.data pipelines
print("\nStep 2: Creating optimized data pipelines...")

train_dataset = create_tf_data_pipeline(train_df, batch_size=32, shuffle=True)
test_dataset = create_tf_data_pipeline(test_df, batch_size=32, shuffle=False)

print("✅ Data pipelines created!")
print(f"   Train batches: {len(list(train_dataset))}")
print(f"   Test batches:  {len(list(test_dataset))}")

# Verify one batch
print("\nStep 3: Verifying data shapes...")
for X_batch, y_batch in train_dataset.take(1):
    print(f"📦 Batch shape: {X_batch.shape}")
    print(f"🎯 Labels shape: {y_batch.shape}")
    print(f"🔢 Sample labels: {y_batch[:5].numpy()}")

# Save the datasets and metadata
print("\nStep 4: Saving pipeline metadata...")

# Save label mapping
import json
with open('label_mapping.json', 'w') as f:
    json.dump(label_mapping, f, indent=2)

# Save dataset info
dataset_info = {
    'total_samples': len(df),
    'train_samples': len(train_df),
    'test_samples': len(test_df),
    'input_shape': (N_MFCC, 216, 1),  # MFCC shape
    'num_classes': len(label_mapping),
    'sample_rate': SAMPLE_RATE,
    'duration': DURATION
}

with open('dataset_info.json', 'w') as f:
    json.dump(dataset_info, f, indent=2)

print("💾 Metadata saved to label_mapping.json and dataset_info.json")

# ==================== READY FOR TRAINING ====================

print("\n" + "="*60)
print("🎉 DATASET PIPELINE READY FOR TRAINING!")
print("="*60)
print("   train_dataset - for training")
print("   test_dataset  - for validation")
print("\nNext steps:")
print("1. Build model architecture")
print("2. train_model.fit(train_dataset, validation_data=test_dataset)")
print("3. Evaluate performance")
# Out:
# 🚀 Building dataset pipeline...
# Step 1: Creating file manifest...
# 📊 Loaded 4000 samples
# 🎯 Classes: ['belly_pain', 'burping', 'cold_hot', 'discomfort', 'hungry', 'lonely', 'noise', 'resampled', 'scared', 'tired']
# 🔢 Label mapping: {'belly_pain': 0, 'burping': 1, 'cold_hot': 2, 'discomfort': 3, 'hungry': 4, 'lonely': 5, 'noise': 6, 'resampled': 7, 'scared': 8, 'tired': 9}
#
# 📈 Dataset split:
#    Training: 3200 samples
#    Testing:  800 samples
#
# Step 2: Creating optimized data pipelines...
# ✅ Data pipelines created!
#    Train batches: 100
#    Test batches:  25
#
# Step 3: Verifying data shapes...
# 📦 Batch shape: (32, 40, 216, 1)
# 🎯 Labels shape: (32,)
# 🔢 Sample labels: [8 9 9 9 9]
#
# Step 4: Saving pipeline metadata...
# 💾 Metadata saved to label_mapping.json and dataset_info.json
#
# ============================================================
# 🎉 DATASET PIPELINE READY FOR TRAINING!
# ============================================================
#    train_dataset - for training
#    test_dataset  - for validation
#
# Next steps:
# 1. Build model architecture
# 2. train_model.fit(train_dataset, validation_data=test_dataset)
# 3. Evaluate performance
